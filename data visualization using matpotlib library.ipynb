# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.array([3,12,15,34,37,41,48,56,67,88])
y = np.array([9,12,15,31,44,51,57,53,67,71])
z = np.array([70,68,65,54,49,51,41,33,21,18])
p = np.array([56,43,26,47,62,15,67,37,66,22])

# %% [markdown]
# ##### Line plot

# %%
plt.plot(x,y)

# %%
plt.plot(x,z)

# %%
plt.plot(x,p)

# %%
plt.title('My First Plot')
plt.xlabel('First Value')
plt.ylabel('Second Value')
plt.grid()
plt.plot(x,y)

# %%
plt.title('My First Plot')
plt.xlabel('First Value')
plt.ylabel('Second Value')
plt.xlim(0,90)
plt.ylim(0,80)
plt.xticks(range(0,91,10))
plt.yticks(range(0,81,10))
plt.grid()
plt.plot(x,y)

# %%
plt.title('My First Plot')
plt.xlabel('First Value')
plt.ylabel('Second Value')
plt.xlim(0,90)
plt.ylim(0,80)
plt.xticks(range(0,91,10))
plt.yticks(range(0,81,10))
plt.grid()
#marker : o  . >  <  v  ^  D  *  
plt.plot(x,y , color = '#6b389e',marker='.',ms=10,mfc='#862b63',ls=':')

# %%
plt.title('Comparison Plot')
plt.xlabel('First Value')
plt.ylabel('Second Value')
plt.xticks(range(0,91,10))
plt.yticks(range(0,81,10))
plt.grid()
plt.plot(x , y ,color='maroon', label='2023')
plt.plot(x , z , color='teal', label='2024')
plt.legend()

# %%
plt.title('Comparison Plot')
plt.xlabel('First Value')
plt.ylabel('Second Value')
plt.xticks(range(0,91,10))
plt.yticks(range(0,81,10))
plt.grid()
plt.plot(x , y ,color='maroon', label='2023')
plt.plot(x , z , color='teal', label='2024')
plt.plot(x , p , color='#922f6c', label='2025')
plt.legend()

# %% [markdown]
# ##### subplots

# %%
plt.subplot(2,1,1)
plt.plot(x,y)
plt.subplot(2,1,2)
plt.plot(x,z)

# %%
plt.subplot(1,2,1)
plt.title('First plot')
plt.grid()
plt.xlabel('First Value')
plt.ylabel('Second Value')
plt.plot(x,y,color='maroon')
plt.subplot(1,2,2)
plt.title('Second plot')
plt.grid()
plt.xlabel('Third Value')
plt.ylabel('Forth Value')
plt.plot(x,z,color='teal')

# %%
plt.subplot(2,2,1)
plt.title('First plot')
plt.grid()
plt.xlabel('First Value')
plt.ylabel('Second Value')
plt.plot(x,y,color='maroon')
plt.subplot(2,2,2)
plt.title('Second plot')
plt.grid()
plt.xlabel('Third  Value')
plt.ylabel('Forth Value')
plt.plot(x,z,color='teal')
plt.subplot(2,2,3)
plt.title('Third plot')
plt.plot(x,p)
plt.subplot(2,2,4)
plt.title('Forth plot')
plt.plot(y,z)

# %%
plt.subplot(2,2,1)
plt.plot(x,y)
plt.subplot(2,2,3)
plt.plot(x,z)
plt.subplot(1,2,2)
plt.plot(x,p)

# %%
plt.figure(figsize=(16,9))
plt.title('My First Plot')
plt.xlabel('First Value')
plt.ylabel('Second Value')
plt.xlim(0,90)
plt.ylim(0,80)
plt.xticks(range(0,91,10))
plt.yticks(range(0,81,10))
plt.grid()
#marker : o  . >  <  v  ^  D  *  
plt.plot(x,y , color = '#6b389e',marker='.',ms=10,mfc='#862b63',ls=':')

# %%
plt.figure(figsize=(10,9))
plt.title('My First Plot')
plt.xlabel('First Value')
plt.ylabel('Second Value')
plt.xlim(0,90)
plt.ylim(0,80)
plt.xticks(range(0,91,10))
plt.yticks(range(0,81,10))
plt.grid()
#marker : o  . >  <  v  ^  D  *  
plt.plot(x,y , color = '#6b389e',marker='.',ms=10,mfc='#862b63',ls=':')

# %%
import pandas as pd

# %%
df = pd.read_csv('Salary_Data.csv')

# %%
df
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
x = df['YearsExperience']

# %%
x
# Out:
# 0      1.1
# 1      1.3
# 2      1.5
# 3      2.0
# 4      2.2
# 5      2.9
# 6      3.0
# 7      3.2
# 8      3.2
# 9      3.7
# 10     3.9
# 11     4.0
# 12     4.0
# 13     4.1
# 14     4.5
# 15     4.9
# 16     5.1
# 17     5.3
# 18     5.9
# 19     6.0
# 20     6.8
# 21     7.1
# 22     7.9
# 23     8.2
# 24     8.7
# 25     9.0
# 26     9.5
# 27     9.6
# 28    10.3
# 29    10.5
# Name: YearsExperience, dtype: float64

# %%
y = df['Salary']

# %%
plt.plot(x , y)

# %%
plt.title('years experience vs salary Plot')
plt.xlabel('YerasExperience ')
plt.ylabel('Salary ')
plt.xlim(0,11)
plt.ylim(35000,120000)
plt.xticks(range(0,12,1))
plt.yticks(range(35000,120000,5000))
plt.grid()
plt.plot(x , y)

# %% [markdown]
# ##### Scatter plot

# %%
x = np.array([3,12,15,34,37,41,48,56,67,88])
y = np.array([9,12,15,31,44,51,57,53,67,71])
z = np.array([70,68,65,54,49,51,41,33,21,18])
p = np.array([56,43,26,47,62,15,67,37,66,22])

# %%
plt.title('My First Plot')
plt.xlabel('First Value')
plt.ylabel('Second Value')
plt.xlim(0,90)
plt.ylim(0,80)
plt.xticks(range(0,91,10))
plt.yticks(range(0,81,10))
plt.grid()
plt.scatter(x,y,color='maroon')

# %% [markdown]
# ##### Bar plot

# %%
studs = [67,89,123,190,104,65,81]
subs = ['C','C++','Java','Python','PHP','JavaScript','R']

# %%
plt.figure(figsize=(16,9))
plt.title('Student Entrollment')
plt.xlabel('Subject name')
plt.ylabel('Total student')
plt.bar(subs,studs,color='teal')
# Out:
# <BarContainer object of 7 artists>

# %%
plt.figure(figsize=(16,9))
plt.title('Student Entrollment')
plt.ylabel('Subject name')
plt.xlabel('Total student')
plt.barh(subs,studs,color='teal')
# Out:
# <BarContainer object of 7 artists>

# %%
openings = [18,56,100,278,167,45,13]

# %%
plt.figure(figsize=(16,9))
plt.title('Student Entrollment')
plt.xlabel('Subject name')
plt.ylabel('Total student')
plt.bar(subs,studs,color='teal',width=0.3,align='edge',label='Students')
plt.bar(subs,openings,color='maroon',width=0.3,align='center',label='openings')
plt.legend()

# %% [markdown]
# ##### Pie chart

# %%
plt.figure(figsize=(5,5))
plt.pie(studs , labels=subs , autopct='%2.2f%%');

# %%
plt.figure(figsize=(5,5))
plt.pie(openings , labels=subs ,autopct='%2.2f%%');

# %% [markdown]
# ##### Histogram

# %%
marks =[56,48,87,67,61,70,76,72,74,58,69,83,57,69,80,57]

# %%
plt.title('Students counts in range')
plt.xticks(range(0,101,10))
plt.grid()
plt.xlabel('Range')
plt.ylabel('Counts')
plt.hist(marks , bins=range(0,100,10));

# %% [markdown]
# ##### Box plot

# %%
marks =[56,48,87,67,61,70,76,72,25,74,58,69,83,57,69,80,57,120]

# %%
plt.boxplot(marks);

# %%
import pandas as pd

# %%
df = pd.read_csv('sales_data.csv')

# %%
df
# Out:
#           Date ProductCategory  Sales Region
# 0   2025-01-01     Electronics   1200  North
# 1   2025-01-02           Books    350  South
# 2   2025-01-03        Clothing    700   East
# 3   2025-01-04     Electronics   1500   West
# 4   2025-01-05           Books    400  North
# 5   2025-01-06        Clothing    850  South
# 6   2025-01-07     Electronics   1300   East
# 7   2025-01-08           Books    380   West
# 8   2025-01-09        Clothing    720  North
# 9   2025-01-10     Electronics   1600  South
# 10  2025-01-11           Books    420   East
# 11  2025-01-12        Clothing    900   West
# 12  2025-01-13     Electronics   1450  North
# 13  2025-01-14           Books    360  South
# 14  2025-01-15        Clothing    780   East
# 15  2025-01-16     Electronics   1700   West
# 16  2025-01-17           Books    450  North
# 17  2025-01-18        Clothing    800  South
# 18  2025-01-19     Electronics   1550   East
# 19  2025-01-20           Books    390   West

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df = df.sort_values('Date')

# %%
plt.figure(figsize=(16, 10))
plt.plot(df['Date'], df['Sales'], marker='.', color='teal')
plt.title('Sales Trend Over Time')
plt.xlabel('Date')
plt.ylabel('Sales')
plt.grid()

# %%
df['Day'] = df['Date'].dt.day

# %%
plt.title('relationship between day of month and sales')
plt.xlabel('Day')
plt.ylabel('Sales')
plt.grid()
plt.scatter(x , y)

# %%
df
# Out:
#          Date ProductCategory  Sales Region  Day
# 0  2025-01-01     Electronics   1200  North    1
# 1  2025-01-02           Books    350  South    2
# 2  2025-01-03        Clothing    700   East    3
# 3  2025-01-04     Electronics   1500   West    4
# 4  2025-01-05           Books    400  North    5
# 5  2025-01-06        Clothing    850  South    6
# 6  2025-01-07     Electronics   1300   East    7
# 7  2025-01-08           Books    380   West    8
# 8  2025-01-09        Clothing    720  North    9
# 9  2025-01-10     Electronics   1600  South   10
# 10 2025-01-11           Books    420   East   11
# 11 2025-01-12        Clothing    900   West   12
# 12 2025-01-13     Electronics   1450  North   13
# 13 2025-01-14           Books    360  South   14
# 14 2025-01-15        Clothing    780   East   15
# 15 2025-01-16     Electronics   1700   West   16
# 16 2025-01-17           Books    450  North   17
# 17 2025-01-18        Clothing    800  South   18
# ...

# %%
grouped = df.groupby('ProductCategory')['Sales'].sum().reset_index()

# %%
category = grouped['ProductCategory'].values  # or .tolist()
salary = grouped['Sales'].values

# %%
plt.figure(figsize=(16, 10))
plt.bar(category, salary, color='skyblue')
plt.xlabel('Product Category')
plt.ylabel('Total Sales')
plt.title('Total Sales by Product Category')
# Out:
# Text(0.5, 1.0, 'Total Sales by Product Category')

# %%
region_sales = df.groupby('Region')['Sales'].sum()

# %%
regions = region_sales['Region']
sales = region_sales['Sales']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Region'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 regions = region_sales['Region']
#       2 sales = region_sales['Sales']
# ...
